# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Ankit Rai\OneDrive\Documents\datasets for practice\Weather dataset.csv")
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# FIND COUNT OF ALL UNIQUE VALUES FOR WIND SPEED

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# FIND THE NUMBER OF TIMES WHEN THE WEATHER IS CLEAR

# %%
data[data['Weather']=='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# FIND THE NUMBER OF TIMES WHEN THE WIND SPEED IS GREATER THAN 10 Km/Hr

# %%
data[data['Wind Speed_km/h']>10]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9        1/1/2012 9:00    -1.3              -3.1         88               15
# 13      1/1/2012 13:00     0.2              -1.7         87               13
# 14      1/1/2012 14:00     0.8              -1.1         87               20
# 15      1/1/2012 15:00     1.8              -0.4         85               22
# 16      1/1/2012 16:00     2.6              -0.2         82               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# WHAT IS THE MEAN OF VISIBILITY?

# %%
data['Visibility_km'].mean()
# Out:
# np.float64(27.664446721311478)

# %% [markdown]
# WHAT IS THE STANDARD DEVIATION OF PRESSURE?

# %%
data['Press_kPa'].std()
# Out:
# np.float64(0.8440047459486483)

# %% [markdown]
# WHAT IS THE VARIANCE OF HUMIDITY?

# %%
data['Rel Hum_%'].var()
# Out:
# np.float64(286.24855019850196)

# %% [markdown]
# FIND ALL INSTANCES WHEN SNOW WAS RECORDED

# %%
data[data['Weather'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# FIND ALL INSTANCES WHEN 'WIND SPEED IS ABOVE 24' AND 'VISIBILITY IS 25'.

# %%
data[(data['Wind Speed_km/h']>24)&(data['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# COUNT OF EACH WEATHER CONDITIONS

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# Calculate the average , maximum and minimum values for Temperature, Humidity,Wind Speed, Pressure and Visibility

# %%
basic_stats= data.describe()
basic_stats.loc[['mean','min','max']]
# Out:
#          Temp_C  Dew Point Temp_C   Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# mean   8.798144          2.555294   67.431694        14.945469      27.664447
# min  -23.300000        -28.500000   18.000000         0.000000       0.200000
# max   33.000000         24.400000  100.000000        83.000000      48.300000
#
#        Press_kPa
# mean  101.051623
# min    97.520000
# max   103.650000

# %% [markdown]
# CORRELATION MATRIX

# %%
correlation_matrix= data[['Temp_C','Dew Point Temp_C','Wind Speed_km/h','Visibility_km','Press_kPa']].corr()
sns.heatmap(correlation_matrix,cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Identify dates of extreme temperature and windspeed

# %%
max_temp_date = data.loc[data['Temp_C'].idxmax(), 'Date/Time']
max_wind_speed = data.loc[data['Wind Speed_km/h'].idxmax(),'Date/Time']
max_temp_date,max_wind_speed
# Out:
# ('6/21/2012 15:00', '1/18/2012 1:00')

# %% [markdown]
# What is the Mean value of each column against each 'Weather Condition ?

# %%
data.groupby('Weather')[['Temp_C','Dew Point Temp_C','Rel Hum_%','Wind Speed_km/h','Visibility_km','Press_kPa']].mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# Daily temperature and humodity pattern

# %%
data['Date/Time']=pd.to_datetime(data['Date/Time']) # converting into date/time format
daily_avg = data.groupby(data['Date/Time'].dt.date)[['Temp_C', 'Rel Hum_%']].mean()
plt.figure(figsize=(12, 6))
plt.plot(daily_avg['Temp_C'], label='Temp_C')
plt.plot(daily_avg['Rel Hum_%'], label='Rel Hum_%')
plt.xlabel('Date/Time')
plt.ylabel('Average Value')
plt.title('Daily Temperature and Humidity Patterns')
plt.legend()
plt.show()

# %% [markdown]
# What is the average temperature and humidity at different times of the day?

# %%
data['hour']=data['Date/Time'].dt.hour
day_avg = data.groupby('hour')[['Temp_C', 'Rel Hum_%','Wind Speed_km/h']].mean()
plt.figure(figsize=(12, 6))
plt.plot(day_avg['Temp_C'], label='Temp_C')
plt.plot(day_avg['Rel Hum_%'], label='Rel Hum_%')
plt.plot(day_avg['Wind Speed_km/h'], label='Wind Speed_km/h')
plt.xlabel('hour')
plt.ylabel('Average Value')
plt.title('Daily Temperature,Humidity and Wind Speed Patterns')
plt.legend()
plt.show()

# %% [markdown]
# Impact of Wind Speed on Temperature and Humidity

# %%
data['Wind_Category']=pd.cut(data['Wind Speed_km/h'],bins=[0,30,60,90],labels=['low','medium','high'])
wind_effect= data.groupby('Wind_Category')[['Temp_C','Rel Hum_%']].mean()
wind_effect
# Out:
# C:\Users\Ankit Rai\AppData\Local\Temp\ipykernel_14812\2522055599.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   wind_effect= data.groupby('Wind_Category')[['Temp_C','Rel Hum_%']].mean()
#                  Temp_C  Rel Hum_%
# Wind_Category
# low            9.044313  67.073793
# medium         5.035321  70.098624
# high           3.066667  62.000000

# %% [markdown]
# Monthly Visibility Analysis

# %%
data['month']=data['Date/Time'].dt.month
monthly_visibility = data.groupby('month')['Visibility_km'].mean()

plt.figure(figsize=(10, 6))
plt.plot(monthly_visibility, marker='o', color='purple')
plt.xlabel('month')
plt.ylabel('Average Visibility')
plt.title('Average Monthly Visibility')
plt.show()

# %% [markdown]
# Outliers

# %%
plt.subplot(1, 2, 1)
sns.boxplot(y=data['Temp_C'], color='orange')
plt.title('Temperature Outliers')
# Out:
# Text(0.5, 1.0, 'Temperature Outliers')

# %%
plt.subplot(1, 2, 1)
sns.boxplot(y=data['Dew Point Temp_C'], color='yellow')
plt.title('Dew Point Temperature Outliers')
# Out:
# Text(0.5, 1.0, 'Dew Point Temperature Outliers')

# %%
plt.subplot(1, 2, 1)
sns.boxplot(y=data['Wind Speed_km/h'], color='red')
plt.title('Wind Speed Outliers')
# Out:
# Text(0.5, 1.0, 'Wind Speed Outliers')
